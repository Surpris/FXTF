# %% [markdown]
# # 目的
# リアルタイム描画を目指す。

# %%
import sys
from FX.FX import rategetter as rg
import copy
import time
from IPython import display

# %%
rg.get_FX_from_gaitame()
# Out:
# (datetime.datetime(2017, 3, 30, 19, 27, 30, 280369), 111.15, 111.14, True)

# %% [markdown]
# ## リアルタイム描画のテスト
# サイン関数でテスト

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(111)
plt.ion()

fig.show()
fig.canvas.draw()
# plt.ion()
x = []
y = []
count = 0
while True:
    try:
        ax.clear()
        x.append(count)
        y.append(np.sin(2.*np.pi*count/60))
        ax.plot(x, y)
        fig.canvas.draw()
        time.sleep(1.0)
        count+=1
#         plt.clf()
    except KeyboardInterrupt:
        break
plt.ioff()
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## 別の方法

# %%
# %matplotlib inline
fig = plt.figure()

x = []
y = []
count = 0
while True:
    try:
        x.append(count)
        y.append(np.sin(2.*np.pi*count/60))
        plt.plot(x, y)
        plt.xlabel("time")
        plt.ylabel("sin")
        plt.grid()
        display.clear_output(wait=True)
        display.display(plt.gcf())
        time.sleep(0.5)
        count+=1
        plt.clf()
    except KeyboardInterrupt:
        plt.clf()
        break

# %% [markdown]
# ## 外部に出力する
